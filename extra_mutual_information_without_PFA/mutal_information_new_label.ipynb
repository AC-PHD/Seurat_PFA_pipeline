# %%
import pandas as pd
import numpy as np
import math
from configparser import ConfigParser

# %%
path_original_data = "PFA_analysis_data.csv"
data = pd.read_csv(path_original_data, sep=',', header=None)
number_output_functions = 1
list_variables = [i for i in range (number_output_functions,data.shape[0]) ]

# %%
def get_mutual_information(data,number_output_functions,list_variables,min_n_datapoints_a_bin,basis_log_mutual_information):
    # Calulate the Shannon mutual information
    def make_summand_from_frequencies(x,y):
        if x == 0:
            return 0
        else:
            return x * math.log2( x / y) / math.log2(basis_log_mutual_information)
    # Insert the the indices of the rows where the components of the output functions are stored
    for i in range(0,number_output_functions):
        list_variables.insert(i,i)
    data_init = data.to_numpy()
    data=data_init[list_variables,:]
    m = data.shape[0]
    n = data.shape[1]
    l = [0 for i in range(0, m)]
    freq_data = [0 for i in range(0, m)]
    left_features = [i for i in range(0, m)]
    constant_features = []
    for i in range(0, m):
        mindata = min(data[i, :])
        maxdata = max(data[i, :])
        if maxdata <= mindata:
            print("Feature #"f"{list_variables[i]}" " has only constant values")
            left_features.remove(i)
            constant_features.append(list_variables[i])
        else:
            # start the binning by sorting the data points
            list_points_of_support = []
            datapoints = data[i, :].copy()
            datapoints.sort()
            last_index = 0
            # go through the data points and bin them
            for point in range(0, datapoints.size):
                if point >= (datapoints.size - 1):  # if end of the data points leave the for-loop
                    break
                # close a bin if there are at least min_n_datapoints_a_bin and the next value is bigger
                if datapoints[last_index:point + 1].size >= min_n_datapoints_a_bin and datapoints[point] < datapoints[point + 1]:
                    list_points_of_support.append(datapoints[point + 1])
                    last_index = point + 1
            if len(list_points_of_support) > 0: # test that there is at least one point of support (it can be if there are only constant value up to the first ones which are less than min_n_datapoints_a_bin
                if list_points_of_support[0] > datapoints[0]: # add the first value as a point of support if it does not exist (less than min_n_datapoints_a_bin at the beginning)
                    list_points_of_support.insert(0, datapoints[0])
            else:
                list_points_of_support.append(datapoints[0])
            list_points_of_support.append(datapoints[-1] + 0.1) # Add last point of support such that last data point is included (half open interals in Python!)
            if datapoints[datapoints >= list_points_of_support[-2]].size < min_n_datapoints_a_bin: # if last bin has not at least min_n_datapoints_a_bin fuse it with the one before the last bin
                if len(list_points_of_support) > 2:     # Test if there are at least 3 points of support (only two can happen if there only constant values at the beginning and only less than n_min_datapoints_a_bin in the end)
                    list_points_of_support.pop(-2)
            l[i] = list_points_of_support
            freq_data[i] = np.histogram(data[i, :], bins=l[i])[0]

    #Check for constant features
    if constant_features != []:
        print("List of features with constant values:")
        print(constant_features)
    for id_output in range(0,number_output_functions):
        if id_output in constant_features or len(freq_data[id_output]) < 2:  # Warn if the output function is constant e.g. due to an unsuitable binning
            print("Warning: Output function " + str(id_output) +  " is constant!")
    # Calculate the mutual information for each feature with the corresponding component of the output function
    list_of_data_frames=[]
    mutual_info = np.ones((1, len(left_features) - number_output_functions + 1))  # number of featuers plus one component of the output-function
    for i in range(0,number_output_functions):
        list_of_features=list(range(number_output_functions,len(left_features)))
        list_of_features.insert(0,i)
        id_features=np.array(list_variables)[left_features]
        for j in list_of_features:
            freq_data_product = ((np.histogram2d(data[i,:], data[left_features[j], :], bins=(l[i], l[left_features[j]]))[0])) / n
            expfreq = (np.outer(freq_data[i], freq_data[left_features[j]])) / (n * n)
            if j<number_output_functions:
                mutual_info[0, 0] = np.sum(np.array(list(map(make_summand_from_frequencies, freq_data_product.flatten().tolist(),expfreq.flatten().tolist()))))
            else:
                mutual_info[0,j-number_output_functions+1]=np.sum(np.array(list(map(make_summand_from_frequencies,freq_data_product.flatten().tolist(),expfreq.flatten().tolist()))))
        pd_mutual_information = pd.DataFrame({"index feature": id_features, "mutual information": mutual_info.tolist()[0]})
        pd_mutual_information['index feature'] = pd_mutual_information['index feature'].astype(int)
        list_of_data_frames.append(pd_mutual_information)
    return list_of_data_frames

mutual_information = get_mutual_information(data,number_output_functions,list_variables,100,2) # (data,number_output_functions,list_variables,min_n_datapoints_a_bin,basis_log_mutual_information)

mutual_information=mutual_information[0]
mutual_information_sorted=mutual_information.sort_values(by=["mutual information"], ascending=False)
mutual_information_sorted.to_csv('gene_mutual_information.csv', index=False)
# Out:
# Feature #82 has only constant values
# Feature #97 has only constant values
# Feature #129 has only constant values
# Feature #138 has only constant values
# Feature #143 has only constant values
# Feature #145 has only constant values
# Feature #177 has only constant values
# Feature #178 has only constant values
# Feature #179 has only constant values
# Feature #184 has only constant values
# Feature #190 has only constant values
# Feature #202 has only constant values
# Feature #216 has only constant values
# Feature #223 has only constant values
# Feature #248 has only constant values
# Feature #250 has only constant values
# Feature #253 has only constant values
# Feature #258 has only constant values
# Feature #266 has only constant values
# Feature #271 has only constant values
# Feature #276 has only constant values
# Feature #295 has only constant values
# Feature #306 has only constant values
# Feature #307 has only constant values
# Feature #331 has only constant values
# Feature #332 has only constant values
# Feature #347 has only constant values
# Feature #360 has only constant values
# Feature #381 has only constant values
# Feature #391 has only constant values
# Feature #396 has only constant values
# Feature #400 has only constant values
# Feature #411 has only constant values
# Feature #418 has only constant values
# Feature #435 has only constant values
# Feature #449 has only constant values
# Feature #461 has only constant values
# Feature #469 has only constant values
# Feature #476 has only constant values
# Feature #494 has only constant values
# Feature #495 has only constant values
# Feature #522 has only constant values
# Feature #525 has only constant values
# Feature #538 has only constant values
# Feature #547 has only constant values
# Feature #555 has only constant values
# Feature #571 has only constant values
# Feature #596 has only constant values
# Feature #619 has only constant values
# Feature #633 has only constant values
# Feature #657 has only constant values
# Feature #665 has only constant values
# Feature #680 has only constant values
# Feature #713 has only constant values
# Feature #741 has only constant values
# Feature #758 has only constant values
# Feature #777 has only constant values
# Feature #780 has only constant values
# Feature #786 has only constant values
# Feature #787 has only constant values
# Feature #790 has only constant values
# Feature #792 has only constant values
# Feature #801 has only constant values
# Feature #803 has only constant values
# Feature #832 has only constant values
# Feature #848 has only constant values
# Feature #853 has only constant values
# Feature #856 has only constant values
# Feature #870 has only constant values
# Feature #879 has only constant values
# Feature #900 has only constant values
# Feature #926 has only constant values
# Feature #934 has only constant values
# Feature #936 has only constant values
# Feature #938 has only constant values
# Feature #960 has only constant values
# Feature #962 has only constant values
# Feature #969 has only constant values
# Feature #973 has only constant values
# Feature #974 has only constant values
# Feature #1003 has only constant values
# Feature #1026 has only constant values
# Feature #1028 has only constant values
# Feature #1041 has only constant values
# Feature #1044 has only constant values
# Feature #1058 has only constant values
# Feature #1075 has only constant values
# Feature #1088 has only constant values
# Feature #1126 has only constant values
# Feature #1141 has only constant values
# Feature #1168 has only constant values
# Feature #1169 has only constant values
# Feature #1175 has only constant values
# Feature #1184 has only constant values
# Feature #1196 has only constant values
# Feature #1210 has only constant values
# Feature #1233 has only constant values
# Feature #1237 has only constant values
# Feature #1238 has only constant values
# Feature #1247 has only constant values
# Feature #1257 has only constant values
# Feature #1258 has only constant values
# Feature #1259 has only constant values
# Feature #1263 has only constant values
# Feature #1269 has only constant values
# Feature #1284 has only constant values
# Feature #1291 has only constant values
# Feature #1295 has only constant values
# Feature #1301 has only constant values
# Feature #1336 has only constant values
# Feature #1337 has only constant values
# Feature #1339 has only constant values
# Feature #1355 has only constant values
# Feature #1362 has only constant values
# Feature #1363 has only constant values
# Feature #1383 has only constant values
# Feature #1425 has only constant values
# Feature #1436 has only constant values
# Feature #1437 has only constant values
# Feature #1449 has only constant values
# Feature #1453 has only constant values
# Feature #1460 has only constant values
# Feature #1461 has only constant values
# Feature #1466 has only constant values
# Feature #1469 has only constant values
# Feature #1474 has only constant values
# Feature #1481 has only constant values
# Feature #1485 has only constant values
# Feature #1486 has only constant values
# Feature #1492 has only constant values
# Feature #1499 has only constant values
# Feature #1505 has only constant values
# Feature #1510 has only constant values
# Feature #1513 has only constant values
# Feature #1518 has only constant values
# Feature #1523 has only constant values
# Feature #1537 has only constant values
# Feature #1580 has only constant values
# Feature #1590 has only constant values
# Feature #1597 has only constant values
# Feature #1607 has only constant values
# Feature #1610 has only constant values
# Feature #1617 has only constant values
# Feature #1622 has only constant values
# Feature #1625 has only constant values
# Feature #1635 has only constant values
# Feature #1652 has only constant values
# Feature #1653 has only constant values
# Feature #1654 has only constant values
# Feature #1677 has only constant values
# Feature #1678 has only constant values
# Feature #1686 has only constant values
# Feature #1688 has only constant values
# Feature #1692 has only constant values
# Feature #1712 has only constant values
# Feature #1715 has only constant values
# Feature #1730 has only constant values
# Feature #1741 has only constant values
# Feature #1745 has only constant values
# Feature #1769 has only constant values
# Feature #1773 has only constant values
# Feature #1784 has only constant values
# Feature #1796 has only constant values
# Feature #1820 has only constant values
# Feature #1847 has only constant values
# Feature #1871 has only constant values
# Feature #1873 has only constant values
# Feature #1878 has only constant values
# Feature #1879 has only constant values
# Feature #1881 has only constant values
# Feature #1904 has only constant values
# Feature #1941 has only constant values
# Feature #1952 has only constant values
# Feature #1971 has only constant values
# Feature #1973 has only constant values
# Feature #1980 has only constant values
# Feature #1987 has only constant values
# Feature #2007 has only constant values
# Feature #2010 has only constant values
# Feature #2018 has only constant values
# Feature #2019 has only constant values
# Feature #2022 has only constant values
# Feature #2024 has only constant values
# Feature #2026 has only constant values
# Feature #2030 has only constant values
# Feature #2041 has only constant values
# Feature #2060 has only constant values
# Feature #2068 has only constant values
# Feature #2073 has only constant values
# Feature #2091 has only constant values
# Feature #2105 has only constant values
# Feature #2167 has only constant values
# Feature #2168 has only constant values
# Feature #2170 has only constant values
# Feature #2191 has only constant values
# Feature #2197 has only constant values
# Feature #2200 has only constant values
# Feature #2216 has only constant values
# Feature #2229 has only constant values
# Feature #2231 has only constant values
# Feature #2232 has only constant values
# Feature #2239 has only constant values
# Feature #2244 has only constant values
# Feature #2248 has only constant values
# Feature #2255 has only constant values
# Feature #2276 has only constant values
# Feature #2285 has only constant values
# Feature #2309 has only constant values
# Feature #2313 has only constant values
# Feature #2315 has only constant values
# Feature #2322 has only constant values
# Feature #2323 has only constant values
# Feature #2332 has only constant values
# Feature #2340 has only constant values
# Feature #2343 has only constant values
# Feature #2362 has only constant values
# Feature #2364 has only constant values
# Feature #2365 has only constant values
# Feature #2370 has only constant values
# Feature #2372 has only constant values
# Feature #2374 has only constant values
# Feature #2384 has only constant values
# Feature #2403 has only constant values
# Feature #2409 has only constant values
# Feature #2414 has only constant values
# Feature #2417 has only constant values
# Feature #2427 has only constant values
# Feature #2440 has only constant values
# Feature #2451 has only constant values
# Feature #2452 has only constant values
# Feature #2515 has only constant values
# Feature #2521 has only constant values
# Feature #2525 has only constant values
# Feature #2555 has only constant values
# Feature #2566 has only constant values
# Feature #2574 has only constant values
# Feature #2577 has only constant values
# Feature #2580 has only constant values
# Feature #2587 has only constant values
# Feature #2588 has only constant values
# Feature #2600 has only constant values
# Feature #2602 has only constant values
# Feature #2612 has only constant values
# Feature #2613 has only constant values
# Feature #2650 has only constant values
# Feature #2651 has only constant values
# Feature #2657 has only constant values
# Feature #2663 has only constant values
# Feature #2672 has only constant values
# Feature #2683 has only constant values
# Feature #2692 has only constant values
# Feature #2696 has only constant values
# Feature #2700 has only constant values
# Feature #2707 has only constant values
# Feature #2711 has only constant values
# Feature #2721 has only constant values
# Feature #2783 has only constant values
# Feature #2784 has only constant values
# Feature #2811 has only constant values
# Feature #2815 has only constant values
# Feature #2831 has only constant values
# Feature #2833 has only constant values
# Feature #2835 has only constant values
# Feature #2843 has only constant values
# Feature #2847 has only constant values
# Feature #2865 has only constant values
# Feature #2894 has only constant values
# Feature #2932 has only constant values
# Feature #2952 has only constant values
# Feature #2961 has only constant values
# Feature #2967 has only constant values
# Feature #2976 has only constant values
# Feature #2987 has only constant values
# Feature #2989 has only constant values
# Feature #3031 has only constant values
# Feature #3033 has only constant values
# Feature #3044 has only constant values
# Feature #3068 has only constant values
# Feature #3070 has only constant values
# Feature #3079 has only constant values
# Feature #3093 has only constant values
# Feature #3126 has only constant values
# Feature #3142 has only constant values
# Feature #3154 has only constant values
# Feature #3163 has only constant values
# Feature #3168 has only constant values
# Feature #3173 has only constant values
# Feature #3187 has only constant values
# Feature #3191 has only constant values
# Feature #3195 has only constant values
# Feature #3197 has only constant values
# Feature #3203 has only constant values
# Feature #3205 has only constant values
# Feature #3208 has only constant values
# Feature #3210 has only constant values
# Feature #3213 has only constant values
# Feature #3222 has only constant values
# Feature #3228 has only constant values
# Feature #3235 has only constant values
# Feature #3238 has only constant values
# Feature #3243 has only constant values
# Feature #3253 has only constant values
# Feature #3254 has only constant values
# Feature #3256 has only constant values
# Feature #3258 has only constant values
# Feature #3259 has only constant values
# Feature #3267 has only constant values
# Feature #3323 has only constant values
# Feature #3331 has only constant values
# Feature #3339 has only constant values
# Feature #3358 has only constant values
# Feature #3369 has only constant values
# Feature #3373 has only constant values
# Feature #3384 has only constant values
# Feature #3397 has only constant values
# Feature #3398 has only constant values
# Feature #3399 has only constant values
# Feature #3410 has only constant values
# Feature #3413 has only constant values
# Feature #3429 has only constant values
# Feature #3434 has only constant values
# Feature #3457 has only constant values
# Feature #3462 has only constant values
# Feature #3463 has only constant values
# Feature #3465 has only constant values
# Feature #3473 has only constant values
# Feature #3478 has only constant values
# Feature #3479 has only constant values
# Feature #3488 has only constant values
# Feature #3493 has only constant values
# Feature #3497 has only constant values
# Feature #3517 has only constant values
# Feature #3526 has only constant values
# Feature #3528 has only constant values
# Feature #3537 has only constant values
# Feature #3538 has only constant values
# Feature #3539 has only constant values
# Feature #3540 has only constant values
# Feature #3564 has only constant values
# Feature #3568 has only constant values
# Feature #3577 has only constant values
# Feature #3578 has only constant values
# Feature #3579 has only constant values
# Feature #3583 has only constant values
# Feature #3584 has only constant values
# Feature #3587 has only constant values
# Feature #3588 has only constant values
# Feature #3597 has only constant values
# Feature #3618 has only constant values
# Feature #3633 has only constant values
# Feature #3652 has only constant values
# Feature #3658 has only constant values
# Feature #3671 has only constant values
# Feature #3672 has only constant values
# Feature #3702 has only constant values
# Feature #3705 has only constant values
# Feature #3732 has only constant values
# Feature #3734 has only constant values
# Feature #3750 has only constant values
# Feature #3774 has only constant values
# Feature #3780 has only constant values
# Feature #3792 has only constant values
# Feature #3805 has only constant values
# Feature #3813 has only constant values
# Feature #3817 has only constant values
# Feature #3826 has only constant values
# Feature #3837 has only constant values
# Feature #3856 has only constant values
# Feature #3863 has only constant values
# Feature #3874 has only constant values
# Feature #3889 has only constant values
# Feature #3896 has only constant values
# Feature #3901 has only constant values
# Feature #3912 has only constant values
# Feature #3920 has only constant values
# Feature #3922 has only constant values
# Feature #3924 has only constant values
# Feature #3928 has only constant values
# Feature #3936 has only constant values
# Feature #3952 has only constant values
# Feature #3957 has only constant values
# Feature #3963 has only constant values
# Feature #4000 has only constant values
# Feature #4005 has only constant values
# Feature #4012 has only constant values
# Feature #4035 has only constant values
# Feature #4037 has only constant values
# Feature #4040 has only constant values
# Feature #4042 has only constant values
# Feature #4047 has only constant values
# Feature #4061 has only constant values
# Feature #4085 has only constant values
# Feature #4091 has only constant values
# Feature #4093 has only constant values
# Feature #4097 has only constant values
# Feature #4123 has only constant values
# Feature #4124 has only constant values
# Feature #4134 has only constant values
# Feature #4169 has only constant values
# Feature #4210 has only constant values
# Feature #4214 has only constant values
# Feature #4225 has only constant values
# Feature #4233 has only constant values
# Feature #4247 has only constant values
# Feature #4250 has only constant values
# Feature #4253 has only constant values
# Feature #4272 has only constant values
# Feature #4275 has only constant values
# Feature #4277 has only constant values
# Feature #4288 has only constant values
# Feature #4306 has only constant values
# Feature #4308 has only constant values
# Feature #4319 has only constant values
# Feature #4340 has only constant values
# Feature #4341 has only constant values
# Feature #4342 has only constant values
# Feature #4345 has only constant values
# Feature #4359 has only constant values
# Feature #4362 has only constant values
# Feature #4371 has only constant values
# Feature #4376 has only constant values
# Feature #4378 has only constant values
# Feature #4379 has only constant values
# Feature #4383 has only constant values
# Feature #4408 has only constant values
# Feature #4417 has only constant values
# Feature #4430 has only constant values
# Feature #4431 has only constant values
# Feature #4437 has only constant values
# Feature #4441 has only constant values
# Feature #4444 has only constant values
# Feature #4452 has only constant values
# Feature #4456 has only constant values
# Feature #4467 has only constant values
# Feature #4473 has only constant values
# Feature #4487 has only constant values
# Feature #4489 has only constant values
# Feature #4501 has only constant values
# Feature #4504 has only constant values
# Feature #4507 has only constant values
# Feature #4523 has only constant values
# Feature #4525 has only constant values
# Feature #4538 has only constant values
# Feature #4540 has only constant values
# Feature #4541 has only constant values
# Feature #4542 has only constant values
# Feature #4544 has only constant values
# Feature #4549 has only constant values
# Feature #4550 has only constant values
# Feature #4556 has only constant values
# Feature #4559 has only constant values
# Feature #4568 has only constant values
# Feature #4570 has only constant values
# Feature #4571 has only constant values
# Feature #4586 has only constant values
# Feature #4594 has only constant values
# Feature #4596 has only constant values
# Feature #4607 has only constant values
# Feature #4610 has only constant values
# Feature #4619 has only constant values
# Feature #4622 has only constant values
# Feature #4631 has only constant values
# Feature #4637 has only constant values
# Feature #4644 has only constant values
# Feature #4651 has only constant values
# Feature #4679 has only constant values
# Feature #4854 has only constant values
# Feature #4889 has only constant values
# Feature #4917 has only constant values
# Feature #4936 has only constant values
# Feature #4944 has only constant values
# Feature #4961 has only constant values
# Feature #5046 has only constant values
# Feature #5114 has only constant values
# Feature #5117 has only constant values
# Feature #5118 has only constant values
# Feature #5124 has only constant values
# Feature #5137 has only constant values
# Feature #5158 has only constant values
# Feature #5178 has only constant values
# Feature #5179 has only constant values
# Feature #5202 has only constant values
# Feature #5216 has only constant values
# Feature #5218 has only constant values
# Feature #5228 has only constant values
# Feature #5237 has only constant values
# Feature #5240 has only constant values
# Feature #5243 has only constant values
# Feature #5244 has only constant values
# Feature #5251 has only constant values
# Feature #5262 has only constant values
# Feature #5272 has only constant values
# Feature #5275 has only constant values
# Feature #5293 has only constant values
# Feature #5299 has only constant values
# Feature #5322 has only constant values
# Feature #5335 has only constant values
# Feature #5350 has only constant values
# Feature #5367 has only constant values
# Feature #5370 has only constant values
# Feature #5377 has only constant values
# Feature #5384 has only constant values
# Feature #5387 has only constant values
# Feature #5392 has only constant values
# Feature #5414 has only constant values
# Feature #5420 has only constant values
# Feature #5451 has only constant values
# Feature #5453 has only constant values
# Feature #5476 has only constant values
# Feature #5481 has only constant values
# Feature #5484 has only constant values
# Feature #5487 has only constant values
# Feature #5503 has only constant values
# Feature #5512 has only constant values
# Feature #5521 has only constant values
# Feature #5535 has only constant values
# Feature #5536 has only constant values
# Feature #5540 has only constant values
# Feature #5542 has only constant values
# Feature #5554 has only constant values
# Feature #5558 has only constant values
# Feature #5562 has only constant values
# Feature #5570 has only constant values
# Feature #5578 has only constant values
# Feature #5589 has only constant values
# Feature #5592 has only constant values
# Feature #5596 has only constant values
# Feature #5615 has only constant values
# Feature #5623 has only constant values
# Feature #5686 has only constant values
# Feature #5706 has only constant values
# Feature #5707 has only constant values
# Feature #5708 has only constant values
# Feature #5709 has only constant values
# Feature #5712 has only constant values
# Feature #5715 has only constant values
# Feature #5741 has only constant values
# Feature #5752 has only constant values
# Feature #5771 has only constant values
# Feature #5775 has only constant values
# Feature #5784 has only constant values
# Feature #5795 has only constant values
# Feature #5796 has only constant values
# Feature #5816 has only constant values
# Feature #5819 has only constant values
# Feature #5823 has only constant values
# Feature #5828 has only constant values
# Feature #5846 has only constant values
# Feature #5854 has only constant values
# Feature #5856 has only constant values
# Feature #5863 has only constant values
# Feature #5877 has only constant values
# Feature #5883 has only constant values
# Feature #5888 has only constant values
# Feature #5895 has only constant values
# Feature #5899 has only constant values
# Feature #5904 has only constant values
# Feature #5907 has only constant values
# Feature #5908 has only constant values
# Feature #5913 has only constant values
# Feature #5914 has only constant values
# Feature #5921 has only constant values
# Feature #5922 has only constant values
# Feature #5936 has only constant values
# Feature #5954 has only constant values
# Feature #5958 has only constant values
# Feature #5965 has only constant values
# Feature #5972 has only constant values
# Feature #5990 has only constant values
# Feature #5991 has only constant values
# Feature #5997 has only constant values
# Feature #6001 has only constant values
# Feature #6007 has only constant values
# Feature #6016 has only constant values
# Feature #6020 has only constant values
# Feature #6026 has only constant values
# Feature #6030 has only constant values
# Feature #6049 has only constant values
# Feature #6052 has only constant values
# Feature #6059 has only constant values
# Feature #6064 has only constant values
# Feature #6086 has only constant values
# Feature #6108 has only constant values
# Feature #6113 has only constant values
# Feature #6131 has only constant values
# Feature #6141 has only constant values
# Feature #6146 has only constant values
# Feature #6149 has only constant values
# Feature #6162 has only constant values
# Feature #6165 has only constant values
# Feature #6168 has only constant values
# Feature #6169 has only constant values
# Feature #6170 has only constant values
# Feature #6195 has only constant values
# Feature #6196 has only constant values
# Feature #6235 has only constant values
# Feature #6239 has only constant values
# Feature #6242 has only constant values
# Feature #6251 has only constant values
# Feature #6256 has only constant values
# Feature #6263 has only constant values
# Feature #6265 has only constant values
# Feature #6280 has only constant values
# Feature #6283 has only constant values
# Feature #6295 has only constant values
# Feature #6301 has only constant values
# Feature #6310 has only constant values
# Feature #6322 has only constant values
# Feature #6329 has only constant values
# Feature #6343 has only constant values
# Feature #6356 has only constant values
# Feature #6357 has only constant values
# Feature #6361 has only constant values
# Feature #6366 has only constant values
# Feature #6373 has only constant values
# Feature #6376 has only constant values
# Feature #6389 has only constant values
# Feature #6391 has only constant values
# Feature #6392 has only constant values
# Feature #6419 has only constant values
# Feature #6423 has only constant values
# Feature #6429 has only constant values
# Feature #6441 has only constant values
# Feature #6443 has only constant values
# Feature #6450 has only constant values
# Feature #6460 has only constant values
# Feature #6472 has only constant values
# Feature #6476 has only constant values
# Feature #6481 has only constant values
# Feature #6503 has only constant values
# Feature #6548 has only constant values
# Feature #6551 has only constant values
# Feature #6554 has only constant values
# Feature #6557 has only constant values
# Feature #6559 has only constant values
# Feature #6567 has only constant values
# Feature #6569 has only constant values
# Feature #6570 has only constant values
# Feature #6616 has only constant values
# Feature #6628 has only constant values
# Feature #6631 has only constant values
# Feature #6643 has only constant values
# Feature #6665 has only constant values
# Feature #6679 has only constant values
# Feature #6681 has only constant values
# Feature #6697 has only constant values
# Feature #6710 has only constant values
# Feature #6711 has only constant values
# Feature #6719 has only constant values
# Feature #6720 has only constant values
# Feature #6725 has only constant values
# Feature #6728 has only constant values
# Feature #6729 has only constant values
# Feature #6732 has only constant values
# Feature #6818 has only constant values
# Feature #6895 has only constant values
# Feature #6897 has only constant values
# Feature #6901 has only constant values
# Feature #6913 has only constant values
# Feature #6996 has only constant values
# Feature #6997 has only constant values
# Feature #7007 has only constant values
# Feature #7021 has only constant values
# Feature #7026 has only constant values
# Feature #7030 has only constant values
# Feature #7038 has only constant values
# Feature #7056 has only constant values
# Feature #7057 has only constant values
# Feature #7074 has only constant values
# Feature #7079 has only constant values
# Feature #7089 has only constant values
# Feature #7094 has only constant values
# Feature #7098 has only constant values
# Feature #7110 has only constant values
# Feature #7154 has only constant values
# Feature #7171 has only constant values
# Feature #7187 has only constant values
# Feature #7194 has only constant values
# Feature #7195 has only constant values
# Feature #7203 has only constant values
# Feature #7216 has only constant values
# Feature #7233 has only constant values
# Feature #7240 has only constant values
# Feature #7256 has only constant values
# Feature #7267 has only constant values
# Feature #7273 has only constant values
# Feature #7279 has only constant values
# Feature #7303 has only constant values
# Feature #7306 has only constant values
# Feature #7309 has only constant values
# Feature #7328 has only constant values
# Feature #7329 has only constant values
# Feature #7337 has only constant values
# Feature #7338 has only constant values
# Feature #7339 has only constant values
# Feature #7340 has only constant values
# Feature #7345 has only constant values
# Feature #7349 has only constant values
# Feature #7359 has only constant values
# Feature #7436 has only constant values
# Feature #7455 has only constant values
# Feature #7717 has only constant values
# Feature #7729 has only constant values
# Feature #7730 has only constant values
# Feature #7731 has only constant values
# Feature #7735 has only constant values
# Feature #7839 has only constant values
# Feature #7850 has only constant values
# Feature #7942 has only constant values
# Feature #7965 has only constant values
# Feature #7989 has only constant values
# Feature #8025 has only constant values
# Feature #8051 has only constant values
# Feature #8121 has only constant values
# Feature #8129 has only constant values
# Feature #8161 has only constant values
# Feature #8193 has only constant values
# Feature #8227 has only constant values
# Feature #8272 has only constant values
# Feature #8283 has only constant values
# Feature #8317 has only constant values
# Feature #8324 has only constant values
# Feature #8349 has only constant values
# Feature #8354 has only constant values
# Feature #8450 has only constant values
# Feature #8453 has only constant values
# Feature #8472 has only constant values
# Feature #8495 has only constant values
# Feature #8506 has only constant values
# Feature #8516 has only constant values
# Feature #8517 has only constant values
# Feature #8613 has only constant values
# Feature #8624 has only constant values
# Feature #8644 has only constant values
# Feature #8667 has only constant values
# Feature #8677 has only constant values
# Feature #8685 has only constant values
# Feature #8703 has only constant values
# Feature #8780 has only constant values
# Feature #8781 has only constant values
# Feature #8847 has only constant values
# Feature #8891 has only constant values
# Feature #8931 has only constant values
# Feature #8939 has only constant values
# Feature #8944 has only constant values
# Feature #9055 has only constant values
# Feature #9068 has only constant values
# Feature #9109 has only constant values
# Feature #9127 has only constant values
# Feature #9145 has only constant values
# Feature #9163 has only constant values
# Feature #9164 has only constant values
# Feature #9217 has only constant values
# Feature #9244 has only constant values
# Feature #9246 has only constant values
# Feature #9253 has only constant values
# Feature #9381 has only constant values
# Feature #9391 has only constant values
# Feature #9460 has only constant values
# Feature #9479 has only constant values
# Feature #9560 has only constant values
# Feature #9598 has only constant values
# Feature #9608 has only constant values
# Feature #9654 has only constant values
# Feature #9678 has only constant values
# Feature #9708 has only constant values
# Feature #9713 has only constant values
# Feature #9755 has only constant values
# Feature #9767 has only constant values
# Feature #9807 has only constant values
# Feature #9820 has only constant values
# Feature #9832 has only constant values
# Feature #9903 has only constant values
# Feature #9907 has only constant values
# Feature #10013 has only constant values
# Feature #10026 has only constant values
# Feature #10138 has only constant values
# Feature #10166 has only constant values
# Feature #10193 has only constant values
# Feature #10195 has only constant values
# Feature #10196 has only constant values
# Feature #10234 has only constant values
# Feature #10261 has only constant values
# Feature #10298 has only constant values
# Feature #10319 has only constant values
# Feature #10321 has only constant values
# Feature #10331 has only constant values
# Feature #10467 has only constant values
# Feature #10477 has only constant values
# Feature #10486 has only constant values
# Feature #10492 has only constant values
# Feature #10540 has only constant values
# Feature #10559 has only constant values
# Feature #10700 has only constant values
# Feature #10701 has only constant values
# Feature #10824 has only constant values
# Feature #10833 has only constant values
# Feature #10841 has only constant values
# Feature #10858 has only constant values
# Feature #10867 has only constant values
# Feature #10876 has only constant values
# Feature #10879 has only constant values
# Feature #10881 has only constant values
# Feature #10887 has only constant values
# Feature #10998 has only constant values
# Feature #11026 has only constant values
# Feature #11038 has only constant values
# Feature #11076 has only constant values
# Feature #11111 has only constant values
# Feature #11205 has only constant values
# Feature #11252 has only constant values
# Feature #11253 has only constant values
# Feature #11256 has only constant values
# Feature #11262 has only constant values
# Feature #11383 has only constant values
# Feature #11405 has only constant values
# Feature #11419 has only constant values
# Feature #11467 has only constant values
# Feature #11524 has only constant values
# Feature #11565 has only constant values
# Feature #11575 has only constant values
# Feature #11576 has only constant values
# Feature #11577 has only constant values
# Feature #11584 has only constant values
# Feature #11618 has only constant values
# Feature #11655 has only constant values
# Feature #11688 has only constant values
# Feature #11750 has only constant values
# Feature #11761 has only constant values
# Feature #11765 has only constant values
# Feature #11768 has only constant values
# Feature #11831 has only constant values
# Feature #11850 has only constant values
# Feature #11868 has only constant values
# Feature #11873 has only constant values
# Feature #11890 has only constant values
# Feature #11909 has only constant values
# Feature #11914 has only constant values
# Feature #11916 has only constant values
# Feature #11960 has only constant values
# Feature #11961 has only constant values
# Feature #12007 has only constant values
# Feature #12036 has only constant values
# Feature #12065 has only constant values
# Feature #12183 has only constant values
# Feature #12241 has only constant values
# Feature #12269 has only constant values
# Feature #12367 has only constant values
# Feature #12377 has only constant values
# Feature #12380 has only constant values
# Feature #12403 has only constant values
# Feature #12417 has only constant values
# Feature #12420 has only constant values
# Feature #12425 has only constant values
# Feature #12429 has only constant values
# Feature #12450 has only constant values
# Feature #12508 has only constant values
# Feature #12513 has only constant values
# Feature #12541 has only constant values
# Feature #12564 has only constant values
# Feature #12579 has only constant values
# Feature #12582 has only constant values
# Feature #12725 has only constant values
# Feature #12760 has only constant values
# Feature #12767 has only constant values
# Feature #12799 has only constant values
# Feature #12803 has only constant values
# Feature #12848 has only constant values
# Feature #12879 has only constant values
# Feature #13028 has only constant values
# Feature #13040 has only constant values
# Feature #13058 has only constant values
# Feature #13065 has only constant values
# Feature #13076 has only constant values
# Feature #13088 has only constant values
# Feature #13089 has only constant values
# Feature #13140 has only constant values
# Feature #13243 has only constant values
# Feature #13307 has only constant values
# Feature #13310 has only constant values
# Feature #13316 has only constant values
# Feature #13341 has only constant values
# Feature #13472 has only constant values
# Feature #13497 has only constant values
# Feature #13498 has only constant values
# Feature #13507 has only constant values
# Feature #13508 has only constant values
# Feature #13512 has only constant values
# Feature #13518 has only constant values
# Feature #13519 has only constant values
# Feature #13528 has only constant values
# Feature #13529 has only constant values
# Feature #13534 has only constant values
# Feature #13536 has only constant values
# Feature #13541 has only constant values
# Feature #13558 has only constant values
# Feature #13677 has only constant values
# Feature #13684 has only constant values
# Feature #13686 has only constant values
# Feature #13746 has only constant values
# Feature #13796 has only constant values
# Feature #13894 has only constant values
# Feature #13895 has only constant values
# Feature #13914 has only constant values
# Feature #13941 has only constant values
# Feature #13945 has only constant values
# Feature #13989 has only constant values
# Feature #13994 has only constant values
# Feature #14011 has only constant values
# Feature #14021 has only constant values
# Feature #14022 has only constant values
# Feature #14053 has only constant values
# Feature #14117 has only constant values
# Feature #14262 has only constant values
# Feature #14263 has only constant values
# Feature #14266 has only constant values
# Feature #14295 has only constant values
# Feature #14326 has only constant values
# Feature #14389 has only constant values
# Feature #14408 has only constant values
# Feature #14412 has only constant values
# Feature #14435 has only constant values
# Feature #14496 has only constant values
# Feature #14533 has only constant values
# Feature #14639 has only constant values
# Feature #14678 has only constant values
# Feature #14723 has only constant values
# Feature #14727 has only constant values
# Feature #14729 has only constant values
# Feature #14733 has only constant values
# Feature #14735 has only constant values
# Feature #14736 has only constant values
# Feature #14775 has only constant values
# Feature #14779 has only constant values
# Feature #14781 has only constant values
# Feature #14788 has only constant values
# Feature #14791 has only constant values
# Feature #14793 has only constant values
# Feature #14860 has only constant values
# Feature #14885 has only constant values
# Feature #14902 has only constant values
# Feature #14921 has only constant values
# Feature #14926 has only constant values
# Feature #15011 has only constant values
# Feature #15030 has only constant values
# Feature #15036 has only constant values
# Feature #15054 has only constant values
# Feature #15055 has only constant values
# Feature #15061 has only constant values
# Feature #15063 has only constant values
# Feature #15067 has only constant values
# Feature #15072 has only constant values
# Feature #15078 has only constant values
# Feature #15082 has only constant values
# Feature #15084 has only constant values
# Feature #15088 has only constant values
# Feature #15093 has only constant values
# Feature #15100 has only constant values
# Feature #15115 has only constant values
# Feature #15120 has only constant values
# Feature #15130 has only constant values
# Feature #15147 has only constant values
# Feature #15157 has only constant values
# Feature #15184 has only constant values
# Feature #15208 has only constant values
# Feature #15299 has only constant values
# Feature #15319 has only constant values
# Feature #15332 has only constant values
# Feature #15341 has only constant values
# Feature #15342 has only constant values
# Feature #15346 has only constant values
# Feature #15352 has only constant values
# Feature #15364 has only constant values
# Feature #15372 has only constant values
# Feature #15386 has only constant values
# Feature #15405 has only constant values
# Feature #15426 has only constant values
# Feature #15428 has only constant values
# Feature #15464 has only constant values
# Feature #15467 has only constant values
# Feature #15472 has only constant values
# Feature #15474 has only constant values
# Feature #15479 has only constant values
# Feature #15490 has only constant values
# Feature #15492 has only constant values
# Feature #15496 has only constant values
# Feature #15508 has only constant values
# Feature #15511 has only constant values
# Feature #15518 has only constant values
# Feature #15520 has only constant values
# Feature #15524 has only constant values
# Feature #15535 has only constant values
# Feature #15552 has only constant values
# Feature #15559 has only constant values
# Feature #15564 has only constant values
# Feature #15568 has only constant values
# Feature #15576 has only constant values
# Feature #15585 has only constant values
# Feature #15589 has only constant values
# Feature #15594 has only constant values
# Feature #15601 has only constant values
# Feature #15608 has only constant values
# Feature #15610 has only constant values
# Feature #15613 has only constant values
# Feature #15620 has only constant values
# Feature #15622 has only constant values
# Feature #15623 has only constant values
# Feature #15674 has only constant values
# Feature #15676 has only constant values
# Feature #15679 has only constant values
# Feature #15686 has only constant values
# Feature #15688 has only constant values
# Feature #15695 has only constant values
# Feature #15697 has only constant values
# Feature #15715 has only constant values
# Feature #15716 has only constant values
# Feature #15724 has only constant values
# Feature #15725 has only constant values
# Feature #15728 has only constant values
# Feature #15733 has only constant values
# Feature #15757 has only constant values
# Feature #15759 has only constant values
# Feature #15760 has only constant values
# Feature #15763 has only constant values
# Feature #15775 has only constant values
# Feature #15779 has only constant values
# Feature #15781 has only constant values
# Feature #15784 has only constant values
# Feature #15785 has only constant values
# Feature #15788 has only constant values
# Feature #15789 has only constant values
# Feature #15790 has only constant values
# Feature #15791 has only constant values
# Feature #15798 has only constant values
# Feature #15801 has only constant values
# Feature #15805 has only constant values
# Feature #15818 has only constant values
# Feature #15838 has only constant values
# Feature #15844 has only constant values
# Feature #15863 has only constant values
# Feature #15865 has only constant values
# Feature #15868 has only constant values
# Feature #15875 has only constant values
# Feature #15880 has only constant values
# Feature #15883 has only constant values
# Feature #15902 has only constant values
# Feature #15903 has only constant values
# Feature #15914 has only constant values
# Feature #15922 has only constant values
# Feature #15926 has only constant values
# Feature #15929 has only constant values
# Feature #15937 has only constant values
# Feature #15939 has only constant values
# Feature #15940 has only constant values
# Feature #15951 has only constant values
# Feature #15964 has only constant values
# Feature #15974 has only constant values
# Feature #15984 has only constant values
# Feature #15989 has only constant values
# Feature #15996 has only constant values
# Feature #16001 has only constant values
# Feature #16015 has only constant values
# Feature #16019 has only constant values
# Feature #16020 has only constant values
# Feature #16031 has only constant values
# Feature #16033 has only constant values
# Feature #16037 has only constant values
# Feature #16043 has only constant values
# Feature #16049 has only constant values
# Feature #16050 has only constant values
# Feature #16100 has only constant values
# Feature #16108 has only constant values
# Feature #16143 has only constant values
# Feature #16149 has only constant values
# Feature #16180 has only constant values
# Feature #16227 has only constant values
# Feature #16229 has only constant values
# Feature #16338 has only constant values
# Feature #16387 has only constant values
# Feature #16402 has only constant values
# Feature #16566 has only constant values
# Feature #16612 has only constant values
# Feature #16614 has only constant values
# Feature #16617 has only constant values
# Feature #16742 has only constant values
# Feature #16881 has only constant values
# Feature #16898 has only constant values
# Feature #16899 has only constant values
# Feature #16902 has only constant values
# Feature #17038 has only constant values
# Feature #17088 has only constant values
# Feature #17220 has only constant values
# Feature #17308 has only constant values
# Feature #17329 has only constant values
# Feature #17332 has only constant values
# Feature #17342 has only constant values
# Feature #17444 has only constant values
# Feature #17451 has only constant values
# Feature #17633 has only constant values
# Feature #17657 has only constant values
# Feature #17740 has only constant values
# Feature #17741 has only constant values
# Feature #17751 has only constant values
# Feature #17792 has only constant values
# Feature #17816 has only constant values
# Feature #17825 has only constant values
# Feature #17906 has only constant values
# Feature #17927 has only constant values
# Feature #17970 has only constant values
# Feature #18019 has only constant values
# Feature #18022 has only constant values
# Feature #18049 has only constant values
# Feature #18056 has only constant values
# Feature #18061 has only constant values
# Feature #18151 has only constant values
# Feature #18198 has only constant values
# Feature #18257 has only constant values
# Feature #18260 has only constant values
# Feature #18261 has only constant values
# Feature #18274 has only constant values
# Feature #18275 has only constant values
# Feature #18277 has only constant values
# Feature #18283 has only constant values
# Feature #18293 has only constant values
# Feature #18297 has only constant values
# Feature #18298 has only constant values
# Feature #18299 has only constant values
# Feature #18300 has only constant values
# Feature #18301 has only constant values
# Feature #18302 has only constant values
# Feature #18379 has only constant values
# Feature #18400 has only constant values
# Feature #18424 has only constant values
# Feature #18455 has only constant values
# Feature #18476 has only constant values
# Feature #18497 has only constant values
# Feature #18502 has only constant values
# Feature #18537 has only constant values
# Feature #18553 has only constant values
# Feature #18563 has only constant values
# Feature #18564 has only constant values
# Feature #18594 has only constant values
# Feature #18596 has only constant values
# Feature #18598 has only constant values
# Feature #18599 has only constant values
# Feature #18604 has only constant values
# Feature #18607 has only constant values
# Feature #18608 has only constant values
# Feature #18696 has only constant values
# Feature #18777 has only constant values
# Feature #18877 has only constant values
# Feature #18919 has only constant values
# Feature #18953 has only constant values
# Feature #19001 has only constant values
# Feature #19026 has only constant values
# Feature #19045 has only constant values
# Feature #19072 has only constant values
# Feature #19074 has only constant values
# Feature #19081 has only constant values
# Feature #19090 has only constant values
# Feature #19094 has only constant values
# Feature #19099 has only constant values
# Feature #19100 has only constant values
# Feature #19101 has only constant values
# Feature #19109 has only constant values
# Feature #19126 has only constant values
# Feature #19186 has only constant values
# Feature #19223 has only constant values
# Feature #19382 has only constant values
# Feature #19383 has only constant values
# Feature #19391 has only constant values
# Feature #19395 has only constant values
# Feature #19444 has only constant values
# Feature #19478 has only constant values
# Feature #19543 has only constant values
# Feature #19647 has only constant values
# Feature #19693 has only constant values
# Feature #19694 has only constant values
# Feature #19702 has only constant values
# Feature #19727 has only constant values
# Feature #19827 has only constant values
# Feature #19867 has only constant values
# Feature #19958 has only constant values
# Feature #20031 has only constant values
# Feature #20053 has only constant values
# Feature #20073 has only constant values
# Feature #20116 has only constant values
# Feature #20240 has only constant values
# Feature #20352 has only constant values
# Feature #20413 has only constant values
# Feature #20444 has only constant values
# Feature #20467 has only constant values
# Feature #20479 has only constant values
# Feature #20504 has only constant values
# Feature #20516 has only constant values
# Feature #20545 has only constant values
# Feature #20546 has only constant values
# Feature #20553 has only constant values
# Feature #20628 has only constant values
# Feature #20656 has only constant values
# Feature #20686 has only constant values
# Feature #20693 has only constant values
# Feature #20750 has only constant values
# Feature #20802 has only constant values
# Feature #20827 has only constant values
# Feature #20838 has only constant values
# Feature #20905 has only constant values
# Feature #20984 has only constant values
# Feature #20993 has only constant values
# Feature #21005 has only constant values
# Feature #21034 has only constant values
# Feature #21069 has only constant values
# Feature #21080 has only constant values
# Feature #21154 has only constant values
# Feature #21196 has only constant values
# Feature #21198 has only constant values
# Feature #21267 has only constant values
# Feature #21312 has only constant values
# Feature #21380 has only constant values
# Feature #21383 has only constant values
# Feature #21389 has only constant values
# ...
# Feature #31031 has only constant values
# Feature #31032 has only constant values
# Feature #31033 has only constant values
# Feature #31034 has only constant values
# Feature #31035 has only constant values
# Feature #31036 has only constant values
# Feature #31037 has only constant values
# Feature #31038 has only constant values
# Feature #31039 has only constant values
# Feature #31040 has only constant values
# Feature #31041 has only constant values
# Feature #31042 has only constant values
# Feature #31043 has only constant values
# Feature #31044 has only constant values
# Feature #31045 has only constant values
# Feature #31046 has only constant values
# Feature #31047 has only constant values
# Feature #31048 has only constant values
# Feature #31049 has only constant values
# Feature #31050 has only constant values
# Feature #31051 has only constant values
# Feature #31052 has only constant values
# Feature #31053 has only constant values
# Feature #31054 has only constant values
# Feature #31055 has only constant values
# Feature #31056 has only constant values
# Feature #31057 has only constant values
# Feature #31058 has only constant values
# Feature #31059 has only constant values
# Feature #31060 has only constant values
# Feature #31061 has only constant values
# Feature #31062 has only constant values
# Feature #31063 has only constant values
# Feature #31064 has only constant values
# Feature #31065 has only constant values
# Feature #31066 has only constant values
# Feature #31067 has only constant values
# Feature #31068 has only constant values
# Feature #31069 has only constant values
# Feature #31070 has only constant values
# Feature #31071 has only constant values
# Feature #31072 has only constant values
# Feature #31073 has only constant values
# Feature #31074 has only constant values
# Feature #31075 has only constant values
# Feature #31076 has only constant values
# Feature #31077 has only constant values
# Feature #31078 has only constant values
# Feature #31079 has only constant values
# Feature #31080 has only constant values
# Feature #31081 has only constant values
# Feature #31082 has only constant values
# Feature #31083 has only constant values
# Feature #31084 has only constant values
# Feature #31085 has only constant values
# Feature #31086 has only constant values
# Feature #31087 has only constant values
# Feature #31088 has only constant values
# Feature #31089 has only constant values
# Feature #31090 has only constant values
# Feature #31091 has only constant values
# Feature #31092 has only constant values
# Feature #31093 has only constant values
# Feature #31094 has only constant values
# Feature #31095 has only constant values
# Feature #31096 has only constant values
# Feature #31097 has only constant values
# Feature #31098 has only constant values
# Feature #31099 has only constant values
# Feature #31100 has only constant values
# Feature #31101 has only constant values
# Feature #31102 has only constant values
# Feature #31103 has only constant values
# Feature #31104 has only constant values
# Feature #31105 has only constant values
# Feature #31106 has only constant values
# Feature #31107 has only constant values
# Feature #31108 has only constant values
# Feature #31109 has only constant values
# Feature #31110 has only constant values
# Feature #31111 has only constant values
# Feature #31112 has only constant values
# Feature #31113 has only constant values
# Feature #31114 has only constant values
# Feature #31115 has only constant values
# Feature #31116 has only constant values
# Feature #31117 has only constant values
# Feature #31118 has only constant values
# Feature #31119 has only constant values
# Feature #31120 has only constant values
# Feature #31121 has only constant values
# Feature #31122 has only constant values
# Feature #31123 has only constant values
# Feature #31124 has only constant values
# Feature #31125 has only constant values
# Feature #31126 has only constant values
# Feature #31127 has only constant values
# Feature #31128 has only constant values
# Feature #31129 has only constant values
# Feature #31130 has only constant values
# Feature #31131 has only constant values
# Feature #31132 has only constant values
# Feature #31133 has only constant values
# Feature #31134 has only constant values
# Feature #31135 has only constant values
# Feature #31136 has only constant values
# Feature #31137 has only constant values
# Feature #31138 has only constant values
# Feature #31139 has only constant values
# Feature #31140 has only constant values
# Feature #31141 has only constant values
# Feature #31142 has only constant values
# Feature #31143 has only constant values
# Feature #31144 has only constant values
# Feature #31145 has only constant values
# Feature #31146 has only constant values
# Feature #31147 has only constant values
# Feature #31148 has only constant values
# Feature #31149 has only constant values
# Feature #31150 has only constant values
# Feature #31151 has only constant values
# Feature #31152 has only constant values
# Feature #31153 has only constant values
# Feature #31154 has only constant values
# Feature #31155 has only constant values
# Feature #31156 has only constant values
# Feature #31157 has only constant values
# Feature #31158 has only constant values
# Feature #31159 has only constant values
# Feature #31160 has only constant values
# Feature #31161 has only constant values
# Feature #31162 has only constant values
# Feature #31163 has only constant values
# Feature #31164 has only constant values
# Feature #31165 has only constant values
# Feature #31166 has only constant values
# Feature #31167 has only constant values
# Feature #31168 has only constant values
# Feature #31169 has only constant values
# Feature #31170 has only constant values
# Feature #31171 has only constant values
# Feature #31172 has only constant values
# Feature #31173 has only constant values
# Feature #31174 has only constant values
# Feature #31175 has only constant values
# Feature #31176 has only constant values
# Feature #31177 has only constant values
# Feature #31178 has only constant values
# Feature #31179 has only constant values
# Feature #31180 has only constant values
# Feature #31181 has only constant values
# Feature #31182 has only constant values
# Feature #31183 has only constant values
# Feature #31184 has only constant values
# Feature #31185 has only constant values
# Feature #31186 has only constant values
# Feature #31187 has only constant values
# Feature #31188 has only constant values
# Feature #31189 has only constant values
# Feature #31190 has only constant values
# Feature #31191 has only constant values
# Feature #31192 has only constant values
# Feature #31193 has only constant values
# Feature #31194 has only constant values
# Feature #31195 has only constant values
# Feature #31196 has only constant values
# Feature #31197 has only constant values
# Feature #31198 has only constant values
# Feature #31199 has only constant values
# Feature #31200 has only constant values
# Feature #31201 has only constant values
# Feature #31202 has only constant values
# Feature #31203 has only constant values
# Feature #31204 has only constant values
# Feature #31205 has only constant values
# Feature #31206 has only constant values
# Feature #31207 has only constant values
# Feature #31208 has only constant values
# Feature #31209 has only constant values
# Feature #31210 has only constant values
# Feature #31211 has only constant values
# Feature #31212 has only constant values
# Feature #31213 has only constant values
# Feature #31214 has only constant values
# Feature #31215 has only constant values
# Feature #31216 has only constant values
# Feature #31217 has only constant values
# Feature #31218 has only constant values
# Feature #31219 has only constant values
# Feature #31220 has only constant values
# Feature #31221 has only constant values
# Feature #31222 has only constant values
# Feature #31223 has only constant values
# Feature #31224 has only constant values
# Feature #31225 has only constant values
# Feature #31226 has only constant values
# Feature #31227 has only constant values
# Feature #31228 has only constant values
# Feature #31229 has only constant values
# Feature #31230 has only constant values
# Feature #31231 has only constant values
# Feature #31232 has only constant values
# Feature #31233 has only constant values
# Feature #31234 has only constant values
# Feature #31235 has only constant values
# Feature #31236 has only constant values
# Feature #31237 has only constant values
# Feature #31238 has only constant values
# Feature #31239 has only constant values
# Feature #31240 has only constant values
# Feature #31241 has only constant values
# Feature #31242 has only constant values
# Feature #31243 has only constant values
# Feature #31244 has only constant values
# Feature #31245 has only constant values
# Feature #31246 has only constant values
# Feature #31247 has only constant values
# Feature #31248 has only constant values
# Feature #31249 has only constant values
# Feature #31250 has only constant values
# Feature #31251 has only constant values
# Feature #31252 has only constant values
# Feature #31253 has only constant values
# Feature #31254 has only constant values
# Feature #31255 has only constant values
# Feature #31256 has only constant values
# Feature #31257 has only constant values
# Feature #31258 has only constant values
# Feature #31259 has only constant values
# Feature #31260 has only constant values
# Feature #31261 has only constant values
# Feature #31262 has only constant values
# Feature #31263 has only constant values
# Feature #31264 has only constant values
# Feature #31265 has only constant values
# Feature #31266 has only constant values
# Feature #31267 has only constant values
# Feature #31268 has only constant values
# Feature #31269 has only constant values
# Feature #31270 has only constant values
# Feature #31271 has only constant values
# Feature #31272 has only constant values
# Feature #31273 has only constant values
# Feature #31274 has only constant values
# Feature #31275 has only constant values
# Feature #31276 has only constant values
# Feature #31277 has only constant values
# Feature #31278 has only constant values
# Feature #31279 has only constant values
# Feature #31280 has only constant values
# Feature #31281 has only constant values
# Feature #31282 has only constant values
# Feature #31283 has only constant values
# Feature #31284 has only constant values
# Feature #31285 has only constant values
# Feature #31286 has only constant values
# Feature #31287 has only constant values
# Feature #31288 has only constant values
# Feature #31289 has only constant values
# Feature #31290 has only constant values
# Feature #31291 has only constant values
# Feature #31292 has only constant values
# Feature #31293 has only constant values
# Feature #31294 has only constant values
# Feature #31295 has only constant values
# Feature #31296 has only constant values
# Feature #31297 has only constant values
# Feature #31298 has only constant values
# Feature #31299 has only constant values
# Feature #31300 has only constant values
# Feature #31301 has only constant values
# Feature #31302 has only constant values
# Feature #31303 has only constant values
# Feature #31304 has only constant values
# Feature #31305 has only constant values
# Feature #31306 has only constant values
# Feature #31307 has only constant values
# Feature #31308 has only constant values
# Feature #31309 has only constant values
# Feature #31310 has only constant values
# Feature #31311 has only constant values
# Feature #31312 has only constant values
# Feature #31313 has only constant values
# Feature #31314 has only constant values
# Feature #31315 has only constant values
# Feature #31316 has only constant values
# Feature #31317 has only constant values
# Feature #31318 has only constant values
# Feature #31319 has only constant values
# Feature #31320 has only constant values
# Feature #31321 has only constant values
# Feature #31322 has only constant values
# Feature #31323 has only constant values
# Feature #31324 has only constant values
# Feature #31325 has only constant values
# Feature #31326 has only constant values
# Feature #31327 has only constant values
# Feature #31328 has only constant values
# List of features with constant values:
# [82, 97, 129, 138, 143, 145, 177, 178, 179, 184, 190, 202, 216, 223, 248, 250, 253, 258, 266, 271, 276, 295, 306, 307, 331, 332, 347, 360, 381, 391, 396, 400, 411, 418, 435, 449, 461, 469, 476, 494, 495, 522, 525, 538, 547, 555, 571, 596, 619, 633, 657, 665, 680, 713, 741, 758, 777, 780, 786, 787, 790, 792, 801, 803, 832, 848, 853, 856, 870, 879, 900, 926, 934, 936, 938, 960, 962, 969, 973, 974, 1003, 1026, 1028, 1041, 1044, 1058, 1075, 1088, 1126, 1141, 1168, 1169, 1175, 1184, 1196, 1210, 1233, 1237, 1238, 1247, 1257, 1258, 1259, 1263, 1269, 1284, 1291, 1295, 1301, 1336, 1337, 1339, 1355, 1362, 1363, 1383, 1425, 1436, 1437, 1449, 1453, 1460, 1461, 1466, 1469, 1474, 1481, 1485, 1486, 1492, 1499, 1505, 1510, 1513, 1518, 1523, 1537, 1580, 1590, 1597, 1607, 1610, 1617, 1622, 1625, 1635, 1652, 1653, 1654, 1677, 1678, 1686, 1688, 1692, 1712, 1715, 1730, 1741, 1745, 1769, 1773, 1784, 1796, 1820, 1847, 1871, 1873, 1878, 1879, 1881, 1904, 1941, 1952, 1971, 1973, 1980, 1987, 2007, 2010, 2018, 2019, 2022, 2024, 2026, 2030, 2041, 2060, 2068, 2073, 2091, 2105, 2167, 2168, 2170, 2191, 2197, 2200, 2216, 2229, 2231, 2232, 2239, 2244, 2248, 2255, 2276, 2285, 2309, 2313, 2315, 2322, 2323, 2332, 2340, 2343, 2362, 2364, 2365, 2370, 2372, 2374, 2384, 2403, 2409, 2414, 2417, 2427, 2440, 2451, 2452, 2515, 2521, 2525, 2555, 2566, 2574, 2577, 2580, 2587, 2588, 2600, 2602, 2612, 2613, 2650, 2651, 2657, 2663, 2672, 2683, 2692, 2696, 2700, 2707, 2711, 2721, 2783, 2784, 2811, 2815, 2831, 2833, 2835, 2843, 2847, 2865, 2894, 2932, 2952, 2961, 2967, 2976, 2987, 2989, 3031, 3033, 3044, 3068, 3070, 3079, 3093, 3126, 3142, 3154, 3163, 3168, 3173, 3187, 3191, 3195, 3197, 3203, 3205, 3208, 3210, 3213, 3222, 3228, 3235, 3238, 3243, 3253, 3254, 3256, 3258, 3259, 3267, 3323, 3331, 3339, 3358, 3369, 3373, 3384, 3397, 3398, 3399, 3410, 3413, 3429, 3434, 3457, 3462, 3463, 3465, 3473, 3478, 3479, 3488, 3493, 3497, 3517, 3526, 3528, 3537, 3538, 3539, 3540, 3564, 3568, 3577, 3578, 3579, 3583, 3584, 3587, 3588, 3597, 3618, 3633, 3652, 3658, 3671, 3672, 3702, 3705, 3732, 3734, 3750, 3774, 3780, 3792, 3805, 3813, 3817, 3826, 3837, 3856, 3863, 3874, 3889, 3896, 3901, 3912, 3920, 3922, 3924, 3928, 3936, 3952, 3957, 3963, 4000, 4005, 4012, 4035, 4037, 4040, 4042, 4047, 4061, 4085, 4091, 4093, 4097, 4123, 4124, 4134, 4169, 4210, 4214, 4225, 4233, 4247, 4250, 4253, 4272, 4275, 4277, 4288, 4306, 4308, 4319, 4340, 4341, 4342, 4345, 4359, 4362, 4371, 4376, 4378, 4379, 4383, 4408, 4417, 4430, 4431, 4437, 4441, 4444, 4452, 4456, 4467, 4473, 4487, 4489, 4501, 4504, 4507, 4523, 4525, 4538, 4540, 4541, 4542, 4544, 4549, 4550, 4556, 4559, 4568, 4570, 4571, 4586, 4594, 4596, 4607, 4610, 4619, 4622, 4631, 4637, 4644, 4651, 4679, 4854, 4889, 4917, 4936, 4944, 4961, 5046, 5114, 5117, 5118, 5124, 5137, 5158, 5178, 5179, 5202, 5216, 5218, 5228, 5237, 5240, 5243, 5244, 5251, 5262, 5272, 5275, 5293, 5299, 5322, 5335, 5350, 5367, 5370, 5377, 5384, 5387, 5392, 5414, 5420, 5451, 5453, 5476, 5481, 5484, 5487, 5503, 5512, 5521, 5535, 5536, 5540, 5542, 5554, 5558, 5562, 5570, 5578, 5589, 5592, 5596, 5615, 5623, 5686, 5706, 5707, 5708, 5709, 5712, 5715, 5741, 5752, 5771, 5775, 5784, 5795, 5796, 5816, 5819, 5823, 5828, 5846, 5854, 5856, 5863, 5877, 5883, 5888, 5895, 5899, 5904, 5907, 5908, 5913, 5914, 5921, 5922, 5936, 5954, 5958, 5965, 5972, 5990, 5991, 5997, 6001, 6007, 6016, 6020, 6026, 6030, 6049, 6052, 6059, 6064, 6086, 6108, 6113, 6131, 6141, 6146, 6149, 6162, 6165, 6168, 6169, 6170, 6195, 6196, 6235, 6239, 6242, 6251, 6256, 6263, 6265, 6280, 6283, 6295, 6301, 6310, 6322, 6329, 6343, 6356, 6357, 6361, 6366, 6373, 6376, 6389, 6391, 6392, 6419, 6423, 6429, 6441, 6443, 6450, 6460, 6472, 6476, 6481, 6503, 6548, 6551, 6554, 6557, 6559, 6567, 6569, 6570, 6616, 6628, 6631, 6643, 6665, 6679, 6681, 6697, 6710, 6711, 6719, 6720, 6725, 6728, 6729, 6732, 6818, 6895, 6897, 6901, 6913, 6996, 6997, 7007, 7021, 7026, 7030, 7038, 7056, 7057, 7074, 7079, 7089, 7094, 7098, 7110, 7154, 7171, 7187, 7194, 7195, 7203, 7 ...
